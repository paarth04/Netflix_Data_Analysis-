# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("NETFLIX_DATASET.csv")  #to load the data

# %%
df.head()  #gives first 5 elements
# Out:
#    index show_id     type                  title         director  \
# 0      1      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      2      s2  TV Show          Blood & Water              NaN
# 2      3      s3  TV Show              Ganglands  Julien Leclercq
# 3      4      s4  TV Show  Jailbirds New Orleans              NaN
# 4      5      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.tail()  #gives  last 5 elements
# Out:
#     index show_id     type                                              title  \
# 95     96     s96  TV Show                                         The Circle
# 96     97     s97    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 97     98     s98  TV Show                                         Kid Cosmic
# 98     99     s99  TV Show                          Octonauts: Above & Beyond
# 99    100    s100  TV Show                                       On the Verge
#
#          director                                               cast  \
# 95            NaN                                    Michelle Buteau
# 96  Stephen Kijak  Ronnie Van Zandt, Gary Rossington, Allen Colli...
# 97            NaN  Jack Fisher, Tom Kenny, Amanda C. Miller, Kim ...
# 98            NaN  Antonio Aakeel, Chipo Chung, Simon Foster, Ter...
# 99            NaN  Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
#
#                           country         date_added  release_year rating  \
# ...

# %%
#-----------------to clean the data----------------
df.dropna(subset =['type','release_year','rating','country','duration','director'])
# Out:
#     index show_id     type                                              title  \
# 0       1      s1    Movie                               Dick Johnson Is Dead
# 7       8      s8    Movie                                            Sankofa
# 8       9      s9  TV Show                      The Great British Baking Show
# 9      10     s10    Movie                                       The Starling
# 12     13     s13    Movie                                       Je Suis Karl
# 24     25     s25    Movie                                              Jeans
# 27     28     s28    Movie                                          Grown Ups
# 28     29     s29    Movie                                         Dark Skies
# 29     30     s30    Movie                                           Paranoia
# 38     39     s39    Movie                                Birth of the Dragon
# 41     42     s42    Movie                                               Jaws
# ...

# %%
#---------"Number of movies VS Shows on netflix"---------------------
type_counts = df['type'].value_counts()
plt.figure(figsize = (6,4))
plt.bar(type_counts.index, type_counts.values,color = ['skyblue','orange'])
plt.title("Number of movies VS Shows on netflix")
plt.xlabel('--Type--')
plt.ylabel('--Count--')
plt.tight_layout()
plt.savefig("movies_VS_tvshoes.png")
plt.show()

# %%
#---------------------"Percentage of Content Ratings"--------------------------
rating_counts = df['rating'].value_counts()
plt.figure(figsize =(6,4))
plt.pie(rating_counts, labels = rating_counts.index,  autopct ='%1.1f%%',startangle = 90)
plt.title("Percentage of Content Ratings")

plt.tight_layout()
plt.savefig("Rating_percentage.png")
plt.show()

# %%
#--------------------------'Distribution of Movie Duration'-----------------------------
movie_df = df[df['type'] == 'Movie'].copy()
movie_df['duration_int'] = movie_df['duration'].str.replace('min','').astype(int)
plt.figure(figsize =(8,6))
plt.hist(movie_df['duration_int'],bins =30, color ='purple', edgecolor = 'black')
plt.xlabel("Duration")
plt.ylabel("Number of files")
plt.tight_layout()
plt.title('Distribution of Movie Duration')
plt.savefig('movie_duration_histogram.png')
plt.show()

# %%
#----------------'Release Year VS Number of shows'----------------------
release_counts = df['release_year'].value_counts().sort_index()
plt.figure(figsize =(10,6))
plt.scatter(release_counts.index, release_counts.values, color ='red')
plt.title('Release Year VS Number of shows')
plt.xlabel('Release Year')
plt.ylabel('Number of shows')
plt.tight_layout()
plt.grid()
plt.savefig('release_year_scatter.png')
plt.show()

# %%
#-------------------'Top 10 Countries by Number of Shows'------------------------
country_counts = df['country'].value_counts().head(10)
plt.figure(figsize =(8,6))
plt.barh(country_counts.index, country_counts.values,color ='teal')
plt.title('Top 10 Countries by Number of Shows')
plt.xlabel('Number of Shows')
plt.ylabel('Country')
plt.tight_layout()
plt.savefig('top10_countries.png')
plt.show()

# %%
#--------------------'Movies released per year'------------------------
content_by_year = df.groupby(['release_year','type']).size().unstack().fillna(0)

fig, ax = plt.subplots(1,2,figsize = (12,5))

#first subplot = movies
ax[0].plot(content_by_year.index, content_by_year['Movie'],color = 'blue')
ax[0].set_title('Movies released per year')
ax[0].set_xlabel('year')
ax[0].set_ylabel('Number of Movies')


#second subplot = TV Show
ax[1].plot(content_by_year.index, content_by_year['TV Show'],color ='red')
ax[1].set_title('TV Show released per year')
ax[1].set_xlabel('year')
ax[1].set_ylabel('Number of Movies')

fig.suptitle("Comparisonn of Movies and TV Shows released over the years")
plt.tight_layout()
plt.savefig('movies_tvshows_comparison.png')
plt.show()
